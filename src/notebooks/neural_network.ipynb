# %%
import sys
import os

project_root = os.path.dirname(os.path.abspath('..')) 

if project_root not in sys.path:
    sys.path.append(project_root)

from src.NeuralNetwork import NeuralNetwork
from src.layers import DenseLayer
import numpy as np

# %%
layers = [
  DenseLayer(
    output_dim = 3,
    activation_name="relu",
    name = "Dense 1"
  ),
  DenseLayer(
    output_dim = 10,
    activation_name="relu",
    name = "Dense 2"
  ),
  DenseLayer(
    output_dim = 5,
    activation_name="relu",
    name = "Dense 3"
  ),
]

nn = NeuralNetwork(
  layers = layers,
  loss_type="mse",
  optimizer_type="momentum",
  seed=1
)

# %%
x = np.random.normal(size = (20, 1000))

nn.build(x.shape[0])

# %%
nn.layers[0].params
# Out:
# {'W': array([[ 0.51366311, -0.19345436, -0.16702257, -0.33930247,  0.27366592,
#          -0.72781044,  0.55175793, -0.24071476,  0.10088902, -0.07885784,
#           0.46235913, -0.65147369, -0.10195727, -0.12144865,  0.35852938,
#          -0.34781616, -0.05452659, -0.27760321,  0.01334916,  0.18430235],
#         [-0.34804634,  0.36199342,  0.28510802,  0.15890266,  0.28487566,
#          -0.21621373, -0.0388613 , -0.29591628, -0.08471365,  0.16771312,
#          -0.21872233, -0.12546448, -0.21730309, -0.26727749, -0.21226666,
#          -0.0040049 , -0.35332456,  0.07412875,  0.52487553,  0.23465497],
#         [-0.06066373, -0.28069292, -0.2362722 ,  0.53520114,  0.01606682,
#          -0.20143571,  0.06037278,  0.66415899,  0.0379976 ,  0.19517676,
#           0.09492219, -0.11139118, -0.36129598, -0.11047187, -0.06605816,
#           0.18550654,  0.26530985,  0.29444033,  0.09031064,  0.27990621]]),
#  'b': array([[0.],
#         [0.],
#         [0.]])}
